# %%
from matplotlib.pyplot import *
from numpy import *
r = linspace(0,10,360)
t_range = linspace(0,2000,360)

x = r*cos(radians(t_range))
y = r*sin(radians(t_range))
plot(x,y,'bo')
axis('equal')
# Out:
# (-10.8449669793266, 9.941634711063568, -9.451275982138558, 10.345781103266757)
